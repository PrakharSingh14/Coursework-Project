# %%
from astropy.io import fits

# %%
file_path = '/home/solararies/Project/Data/data_2/raster_data2/iris_l2_20220306_222300_3620257421_raster_t000_r00000.fits'
hdul=fits.open(file_path)

# %%
hdul.info()
# Out:
# Filename: /home/solararies/Project/Data/data_2/raster_data2/iris_l2_20220306_222300_3620257421_raster_t000_r00000.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     380   ()
#   1                1 ImageHDU        33   (190, 1093, 4)   int16 (rescales to float32)
#   2                1 ImageHDU        33   (125, 1093, 4)   int16 (rescales to float32)
#   3                1 ImageHDU        33   (173, 1093, 4)   int16 (rescales to float32)
#   4                1 ImageHDU        33   (210, 1093, 4)   int16 (rescales to float32)
#   5                1 ImageHDU        33   (305, 1093, 4)   int16 (rescales to float32)
#   6                1 ImageHDU        33   (119, 1093, 4)   int16 (rescales to float32)
#   7                1 ImageHDU        33   (152, 1093, 4)   int16 (rescales to float32)
#   8                1 ImageHDU        33   (537, 1093, 4)   int16 (rescales to float32)
# ...

# %%
hdr = hdul[9].header
data=hdul[8].data
#hdr['CDELT1']

# %%
print(data[2])
# Out:
# [[-200. -200. -200. ... -200. -200. -200.]
#  [-200. -200. -200. ... -200. -200. -200.]
#  [-200. -200. -200. ... -200. -200. -200.]
#  ...
#  [-200. -200. -200. ... -200. -200. -200.]
#  [-200. -200. -200. ... -200. -200. -200.]
#  [-200. -200. -200. ... -200. -200. -200.]]

# %%
import matplotlib.pyplot as plt



plt.figure()
plt.imshow(data[0,:,:], origin='lower',cmap='hot',vmin=1, vmax=60)
plt.show()
